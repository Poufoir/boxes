# %%
import tempfile
import os
from IPython.display import SVG, display
from boxes.generators.rack_box import DividerTray
b = DividerTray(sx="102", sy=[40, 40, 35, 15], bottom_wall=True, h=45)
# fd, fn = tempfile.mkstemp()
fn = "rack_box.svg"
b.parseArgs(['--reference=0', '--debug=0', '--output=' + fn])
b.open()
b.render()
b.close()

display(SVG(fn))
# os.close(fd)
# os.remove(fn)
