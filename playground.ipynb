# %%
from IPython.display import SVG, display
from boxes.generators.rack_box import DividerTray
fn = "rack_box.svg"
b = DividerTray(sx=[108], sy=[40, 40, 35, 15], bottom=True, h=45, reference=0, debug=0, output=fn, labels=True)
b.open()
b.render()
b.close()

display(SVG(fn))

# %%
from IPython.display import SVG, display
from boxes.generators.burntest import BurnTest
fn = "box.svg"
b = BurnTest(reference=0, debug=0, output=fn, labels=True)
b.open()
b.render()
b.close()

display(SVG(fn))
