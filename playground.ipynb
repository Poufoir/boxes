# %%
from IPython.display import SVG, display
from boxes.generators.rack_box import DividerTray
fn = "rack_box.svg"
b = DividerTray(sx=[108], sy=[40, 40, 35, 15], bottom=True, h=45, reference=0, debug=0, output=fn, labels=True)
b.open()
b.render()
b.close()

display(SVG(fn))

# %%
from IPython.display import SVG, display
from boxes.generators.new_box import ABox
fn = "abox.svg"
b = ABox(output=fn)
b.open()
b.render()
b.close()

display(SVG(fn))
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# Cell In[2], line 9
#       6 b.render()
#       7 b.close()
# ----> 9 display(SVG(fn))
#
# File ~/anaconda3/envs/boxes_env/lib/python3.10/site-packages/IPython/core/display.py:320, in DisplayObject.__init__(self, data, url, filename, metadata)
#     316 self.filename = filename
#     317 # because of @data.setter methods in
#     318 # subclasses ensure url and filename are set
#     319 # before assigning to self.data
# --> 320 self.data = data
#     322 if metadata is not None:
#     323     self.metadata = metadata
#
# File ~/anaconda3/envs/boxes_env/lib/python3.10/site-packages/IPython/core/display.py:491, in SVG.data(self, svg)
#     489 # parse into dom object
#     490 from xml.dom import minidom
# --> 491 x = minidom.parseString(svg)
#     492 # get svg tag (should be 1)
#     493 found_svg = x.getElementsByTagName('svg')
# ...

# %%
from IPython.display import SVG, display
from boxes.generators.universalbox import UniversalBox
b = UniversalBox(top_edge="i")
fn = "universal_box.svg"
b.parseArgs(['--reference=0', '--debug=0', '--output=' + fn])
b.open()
b.render()
b.close()

display(SVG(fn))
# Out:
# FingerJoint
# Stackable
# Hinge
# CabinetHinge
# SlideOnLid
# Click
# RoundedTriangleEdge
# Mounting
# HandleEdge
# Flex
# Lid
# usage: ipykernel_launcher.py [-h] [--FingerJoint_angle FINGERJOINT_ANGLE]
#                              [--FingerJoint_style {rectangular,springs,barbs,snap}]
#                              [--FingerJoint_surroundingspaces FINGERJOINT_SURROUNDINGSPACES]
#                              [--FingerJoint_bottom_lip FINGERJOINT_BOTTOM_LIP]
#                              [--FingerJoint_edge_width FINGERJOINT_EDGE_WIDTH]
#                              [--FingerJoint_extra_length FINGERJOINT_EXTRA_LENGTH]
#                              [--FingerJoint_finger FINGERJOINT_FINGER]
#                              [--FingerJoint_play FINGERJOINT_PLAY]
#                              [--FingerJoint_space FINGERJOINT_SPACE]
#                              [--FingerJoint_width FINGERJOINT_WIDTH]
#                              [--Stackable_angle STACKABLE_ANGLE]
# ...
