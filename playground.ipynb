# %%
from IPython.display import SVG, display
from boxes.generators.rack_box import DividerTray
fn = "rack_box.svg"
b = DividerTray(sx=[108], sy=[40, 40, 35, 15], bottom=True, h=45, reference=0, debug=0, output=fn, labels=True)
b.open()
b.render()
b.close()

display(SVG(fn))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/git_projects/boxes/boxes/__init__.py:764, in Boxes.adjustSize(self, square, e1, e2)
#     763 try:
# --> 764     if total > 0.0:
#     765         factor = (total - walls) / total
#
# TypeError: '>' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /home/clement/git_projects/boxes/playground.ipynb Cell 1 line 6
#       <a href='vscode-notebook-cell:/home/clement/git_projects/boxes/playground.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> b = DividerTray(sx="108", sy=[40, 40, 35, 15], bottom=True, h=45, reference=0, debug=0, output=fn, labels=True)
#       <a href='vscode-notebook-cell:/home/clement/git_projects/boxes/playground.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> b.open()
# ----> <a href='vscode-notebook-cell:/home/clement/git_projects/boxes/playground.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> b.render()
#       <a href='vscode-notebook-cell:/home/clement/git_projects/boxes/playground.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> b.close()
#       <a href='vscode-notebook-cell:/home/clement/git_projects/boxes/playground.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> display(SVG(fn))
#
# File ~/git_projects/boxes/boxes/generators/rack_box.py:158, in DividerTray.render(self)
#     156 # If measures are outside, we need to readjust slots afterwards
#     157 if self.outside:
# --> 158     self.sx = self.adjustSize(self.sx, self.left_wall, self.right_wall)
#     159     side_wall_target_length = sum(self.sy) - 2 * self.thickness
#     160     slot_descriptions.adjust_to_target_length(side_wall_target_length)
#
# File ~/git_projects/boxes/boxes/__init__.py:770, in Boxes.adjustSize(self, square, e1, e2)
#     768     return [s * factor for s in square]
#     769 except TypeError:
# --> 770     return square - walls
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
from IPython.display import SVG, display
from boxes.generators.universalbox import UniversalBox
b = UniversalBox(top_edge="i")
fn = "universal_box.svg"
b.parseArgs(['--reference=0', '--debug=0', '--output=' + fn])
b.open()
b.render()
b.close()

display(SVG(fn))
