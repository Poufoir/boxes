# %%
from IPython.display import SVG, display
from boxes.generators.rack_box import DividerTray
fn = "rack_box.svg"
b = DividerTray(sx=[112], sy=[40, 40, 35, 15], bottom=True, h=45, reference=0, debug=0, output=fn, labels=True)
b.open()
b.render()
b.close()

display(SVG(fn))

# %%
from IPython.display import SVG, display
from boxes.generators.slidingdrawer import SlidingDrawer
fn = "box.svg"
b = SlidingDrawer(reference=0, debug=0, output=fn, labels=True, h=20, )
b.open()
b.render()
b.close()

display(SVG(fn))

# %%
from IPython.display import SVG, display
from boxes.generators.slidingdrawer import SlidingDrawer
fn = "box.svg"
b = SlidingDrawer(reference=0, debug=0, output=fn, labels=True, h=30, )
b.open()
b.render()
b.close()

display(SVG(fn))
